# %%
# Paso 1: Cargar las librerías
# Librería para gráficas
import matplotlib.pyplot as plt

# Paso 2: Cargamos los datos
presion_sonora = [63.7, 75.0, 70.5, 72.1, 67.2, 65.1, 59.6, 64.1, 61.1, 62.0,
                  66.9, 76.3, 73.7, 74.1, 62.3, 55.3, 70.6, 53.3, 65.9, 64.0,
                  66.8, 71.4, 71.0, 76.5, 69.4, 71.3, 65.3, 62.5, 62.6, 58.7,
                  75.3, 77.4, 56.1, 57.3, 60.5, 72.3, 74.0, 62.3, 50.2, 68.2,
                  70.8, 71.6, 69.0, 71.6, 75.0, 64.6, 74.9, 75.4, 50.9, 61.6]

# Generar la gráfica de Histograma
plt.hist(x=presion_sonora)
plt.title('Ruido ambiental en la ciudad de Cali')
plt.xlabel('Niveles de presión sonora (dB)')
plt.ylabel('Frecuencias absolutas')
plt.grid()
plt.show()
