# %%
# Paso 1: Cargar las librerías
# Librería para gráficas
import matplotlib.pyplot as plt

# Paso 2: Cargamos los datos
x = ['Deportes', 'Cultura', 'Sociedad', 'Tecnología', 'Otros']
y = [22.1, 20.3, 19.9, 17.9, 19.8]

# Paso 3: Generamos la gráfica de Pie
plt.pie(y, labels=x, autopct="%0.1f %%")
plt.title("Visitas a Contenidos")
plt.show()
