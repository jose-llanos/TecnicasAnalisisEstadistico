# %%
# Paso 1: Cargar las librerías
# Librería para gráficas
import matplotlib.pyplot as plt

# Paso 2: Cargamos los datos
salarios = [1500, 1200, 650, 1000, 3000, 2300, 800, 1800, 700, 2000, 900, 1350, 2700, 1900, 1750, 
            1500, 2000, 2500, 900, 1300, 2400, 1600, 3300, 2200, 3000, 1000, 1500, 2700, 1800, 1200]
gastos = [1300, 700, 600, 900, 2500, 1800, 700, 1450, 500, 1700, 700, 1300, 2300, 1600, 1250,
          1000, 1200, 1350, 900, 950, 1250, 1300, 1500, 1100, 1400, 900, 1100, 1200, 1200, 1000]

# Generar la gráfica de Puntos
plt.scatter(salarios, gastos, label="", color="blue")
plt.xlabel('Salario mensual ($)')
plt.ylabel('Gasto mensual ($)')
plt.grid()
plt.show()
